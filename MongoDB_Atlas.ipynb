# %% [markdown]
# # Example of connecting to MongoDB Atlas
#
# This example is using the free tier of MongoDB Atlas using the pymongo library.
#
# For this you would need to create your own instance and save the connection string which is in the format:
#
# "mongodb+srv://<username>:<password>@<cluster-name>/test?retryWrites=true&w=majority"

# %%
# !pip install pymongo python-decouple

# %% [markdown]
# # Insert data into new collection
#
# The example will insert a  'Hello World' example document to test the connectivity and as a basic test, creation of a database and collection and data
#
# ![image.png](data:image/png;base64,...)

# %%
from pymongo import MongoClient

def database_ops():

   # Provide the mongodb atlas url to connect python to mongodb using pymongo
   USERNAME = "testuser"
   PASSWORD = "SvXkvJIcwIJvTFCm"

   connection_string = f"mongodb+srv://{USERNAME}:\{PASSWORD}@cluster0.ymkpz6v.mongodb.net/?retryWrites=true&w=majority"

   # CONNECTION_STRING = f"mongodb+srv://testuser:SvXkvJIcwIJvTFCm@cluster0.ymkpz6v.mongodb.net/?retryWrites=true&w=majority"

   # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
   client = MongoClient(connection_string)

   # accessing the database called 'local'
   local_db = client.local
   # accessing the collections in the 'local' database
   local_db_collections = local_db.list_collection_names()
   print(local_db_collections)

   # create a database,
   library_db = client.library_db
   # create a collection inside a database
   book_collection = library_db.books

   # create a collection inside a database
   databases = client.list_database_names()
   print(databases)

   books_data = [
    {
        "author": "Hans Christian Andersen",
        "country": "Denmark",
        "imageLink": "images/fairy-tales.jpg",
        "language": "Danish",
        "link": "https://en.wikipedia.org/wiki/Fairy_Tales_Told_for_Children._First_Collection.\n",
        "pages": 784,
        "title": "Fairy tales",
        "year": 1836
    },
    {
        "author": "Dante Alighieri",
        "country": "Italy",
        "imageLink": "images/the-divine-comedy.jpg",
        "language": "Italian",
        "link": "https://en.wikipedia.org/wiki/Divine_Comedy\n",
        "pages": 928,
        "title": "The Divine Comedy",
        "year": 1315
    },
    {
        "author": "Unknown",
        "country": "Sumer and Akkadian Empire",
        "imageLink": "images/the-epic-of-gilgamesh.jpg",
        "language": "Akkadian",
        "link": "https://en.wikipedia.org/wiki/Epic_of_Gilgamesh\n",
        "pages": 160,
        "title": "The Epic Of Gilgamesh",
        "year": -1700
    },
    {
        "author": "Unknown",
        "country": "Achaemenid Empire",
        "imageLink": "images/the-book-of-job.jpg",
        "language": "Hebrew",
        "link": "https://en.wikipedia.org/wiki/Book_of_Job\n",
        "pages": 176,
        "title": "The Book Of Job",
        "year": -600
    }
   ]

   books = book_collection.insert_many(books_data)
   print(books.inserted_ids)

   books = book_collection.find()
   for book in books:
    print(book)


database_ops()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-17-5c6c97724896> in <cell line: 19>()
#      17    print(databases)
#      18
# ---> 19 get_database()
#
# <ipython-input-17-5c6c97724896> in get_database()
#      14    client = MongoClient(connection_string)
#      15
# ---> 16    databases = client.list_database_names()
#      17    print(databases)
#      18
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in list_database_names(self, session, comment)
#    1995         .. versionadded:: 3.6
#    1996         """
# -> 1997         return [doc["name"] for doc in self.list_databases(session, nameOnly=True, comment=comment)]
#    1998
#    1999     @_csot.apply
#
# /usr/local/lib/python3.10/dist-packages/pymongo/mongo_client.py in list_databases(self, session, comment, **kwargs)
#    1968             cmd["comment"] = comment
# ...

# %% [markdown]
# issues
#
# At times I would encounter time out issues to Atlas:
#
# ![image.png](data:image/png;base64,...)
#
# Or SSL connection errors
#
#
# ![image.png](data:image/png;base64,...)
